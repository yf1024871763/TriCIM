# %%
from _tests import scripts
from scripts.notebook_utils import *
from scripts import utils as utl
#result = run_test("pimca", "test_area_breakdown")
results = utl.quick_run(macro="pimca",dnn="vgg16",layer="01")
print("------------------------------")
print("计算量",results.computes)
print("------------------------------")
print("周期数",results.cycles)
print("------------------------------")
print("各元件能量",results.per_component_energy)
print("------------------------------")
print("能量",results.energy)
print("------------------------------")
print("各元件面积",results.per_component_area)
print("------------------------------")
print("吞吐率",results.tops)
print("TOPS/W",results.tops_per_w)
# Out:
# {'macro': 'pimca', 'system': 'ws_dummy_buffer_one_macro', 'iso': 'pimca', 'dnn': 'vgg16', 'layer': '01'}
# ------------------------------
# 计算量 14797504512.0
# ------------------------------
# 周期数 451584
# ------------------------------
# 各元件能量 {'virtual_bitwise_mac': 0.0, 'here_to_fix_a_bug': 0.0, 'bitcell_capacitor': 3.25545099264e-05, 'cim_unit': 1.4797504512e-08, 'inter_row_spatial': 0.0, 'adc': 1.1423673483264e-05, 'inter_column_spatial': 0.0, 'column_drivers': 0.0, 'weight_drivers': 0.0, 'row_drivers': 1.5981304872960002e-05, 'dummy_top': 0.0, 'adc <==> inter_row_spatial': 0.0, 'bitcell_capacitor <==> here_to_fix_a_bug': 0.0, 'cim_unit <==> bitcell_capacitor': 0.0, 'column_drivers <==> inter_column_spatial': 0.0, 'dummy_top <==> row_drivers': 0.0, 'here_to_fix_a_bug <==> virtual_bitwise_mac': 0.0, 'inter_column_spatial <==> adc': 0.0, 'inter_row_spatial <==> cim_unit': 0.0, 'row_drivers <==> weight_drivers': 0.0, 'weight_drivers <==> column_drivers': 0.0}
# ------------------------------
# 能量 5.9974285787136e-05
# ------------------------------
# 各元件面积 {'bitcell_capacitor': 0.0, 'dummy_top': 0.0, 'row_drivers': 1.0489657724e-08, 'weight_drivers': 1.0489657724e-08, 'column_drivers': 0.0, 'inter_column_spatial': 0.0, 'adc': 2.77360217856e-07, 'inter_row_spatial': 0.0, 'cim_unit': 1.1279007744e-08, 'here_to_fix_a_bug': 0.0, 'virtual_bitwise_mac': 0.0, 'adc <==> inter_row_spatial': 0, 'bitcell_capacitor <==> here_to_fix_a_bug': 0, 'cim_unit <==> bitcell_capacitor': 0, 'column_drivers <==> inter_column_spatial': 0, 'dummy_top <==> row_drivers': 0, 'here_to_fix_a_bug <==> virtual_bitwise_mac': 0, 'inter_column_spatial <==> adc': 0, 'inter_row_spatial <==> cim_unit': 0, 'row_drivers <==> weight_drivers': 0, 'weight_drivers <==> column_drivers': 0}
# ------------------------------
# 吞吐率 2.62144
# TOPS/W 493.46163335800645

# %%
from _tests import scripts
from scripts.notebook_utils import *
from scripts import utils as utl
#result = run_test("pimca", "test_area_breakdown")
results = utl.quick_run(macro="pimca",tile="pimca",dnn="vgg16",layer="01")
print("------------------------------")
print("计算量",results.computes)
print("------------------------------")
print("周期数",results.cycles)
print("------------------------------")
print("各元件能量",results.per_component_energy)
print("------------------------------")
print("能量",results.energy)
print("------------------------------")
print("各元件面积",results.per_component_area)
print("------------------------------")
print("吞吐率",results.tops)
print("TOPS/W",results.tops_per_w)
# Out:
# {'macro': 'pimca', 'tile': 'pimca', 'system': 'ws_dummy_buffer_one_macro', 'iso': 'pimca', 'dnn': 'vgg16', 'layer': '01'}
# WARNING:ArrayProcessor:To fill up pe_cluster, multiplied C by (6): (256) -> (1536)
# ------------------------------
# 计算量 1598130487296.0
# ------------------------------
# 周期数 451584
# ------------------------------
# 各元件能量 {'virtual_bitwise_mac': 0.0, 'here_to_fix_a_bug': 0.0, 'bitcell_capacitor': 0.0035158870720512, 'cim_unit': 1.598130487296e-06, 'inter_row_spatial': 0.0, 'adc': 0.001233756736192512, 'inter_column_spatial': 0.0, 'column_drivers': 0.0, 'weight_drivers': 0.0, 'row_drivers': 0.0017259809262796801, 'inter_macro_in_tile_spatial': 0.0, 'inter_pe_cluster_spatial': 0.0, 'dummy_top': 0.0, 'adc <==> inter_row_spatial': 0.0, 'bitcell_capacitor <==> here_to_fix_a_bug': 0.0, 'cim_unit <==> bitcell_capacitor': 0.0, 'column_drivers <==> inter_column_spatial': 0.0, 'dummy_top <==> inter_pe_cluster_spatial': 0.0, 'here_to_fix_a_bug <==> virtual_bitwise_mac': 0.0, 'inter_column_spatial <==> adc': 0.0, 'inter_macro_in_tile_spatial <==> row_drivers': 0.0, 'inter_pe_cluster_spatial <==> inter_macro_in_tile_spatial': 0.0, 'inter_row_spatial <==> cim_unit': 0.0, 'row_drivers <==> weight_drivers': 0.0, 'weight_drivers <==> column_drivers': 0.0}
# ------------------------------
# 能量 0.0064772228650106884
# ------------------------------
# 各元件面积 {'bitcell_capacitor': 0.0, 'dummy_top': 0.0, 'inter_pe_cluster_spatial': 0.0, 'inter_macro_in_tile_spatial': 0.0, 'row_drivers': 1.132883034192e-06, 'weight_drivers': 1.132883034192e-06, 'column_drivers': 0.0, 'inter_column_spatial': 0.0, 'adc': 2.9954903528448e-05, 'inter_row_spatial': 0.0, 'cim_unit': 1.218132836352e-06, 'here_to_fix_a_bug': 0.0, 'virtual_bitwise_mac': 0.0, 'adc <==> inter_row_spatial': 0, 'bitcell_capacitor <==> here_to_fix_a_bug': 0, 'cim_unit <==> bitcell_capacitor': 0, 'column_drivers <==> inter_column_spatial': 0, 'dummy_top <==> inter_pe_cluster_spatial': 0, 'here_to_fix_a_bug <==> virtual_bitwise_mac': 0, 'inter_column_spatial <==> adc': 0, 'inter_macro_in_tile_spatial <==> row_drivers': 0, 'inter_pe_cluster_spatial <==> inter_macro_in_tile_spatial': 0, 'inter_row_spatial <==> cim_unit': 0, 'row_drivers <==> weight_drivers': 0, 'weight_drivers <==> column_drivers': 0}
# ------------------------------
# 吞吐率 283.11552
# TOPS/W 493.4616333580064
